# %% [markdown]
# Build a regression model.

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
citybike_df=pd.read_csv('joindf_clean.cvs', sep=',')
citybike_df
# Out:
#                                           Station_name  Available_bikes  \
# 0                                 Cégep Marie-Victorin               10
# 1        Gare d'autocars de Montréal (Berri / Ontario)                1
# 2                            Molson / William-Tremblay                4
# 3    Ateliers municipaux de St-Laurent (Cavendish /...                9
# 4    Place Rodolphe-Rousseau (Gohier / Édouard-Laurin)               14
# ..                                                 ...              ...
# 757                             Jean-Talon / de l'Épée                6
# 758                           Gare LaSalle (Highlands)                6
# 759          Métro St-Michel (Shaughnessy / St-Michel)                4
# 760                          St-Hubert / René-Levesque                0
# 761                                Durocher / Beaumont               11
#
#      Empty_slots  Longitude   Latitude  Count_4SQUARE_POI  Count_Yelp_POI
# ...

# %%
import statsmodels.api as sm
y = citybike_df[['Available_bikes']]
X = citybike_df[['Count_4SQUARE_POI', 
                'Count_Yelp_POI',
                'Empty_slots']]
X = sm.add_constant(X)
X.head()
# Out:
#    const  Count_4SQUARE_POI  Count_Yelp_POI  Empty_slots
# 0    1.0                 11               0            1
# 1    1.0                 50              14           13
# 2    1.0                 20               0            9
# 3    1.0                  0               0            8
# 4    1.0                 22               0           11

# %%
model = sm.OLS(y, X) 
results = model.fit() 
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Available_bikes   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     223.8
# Date:                Tue, 04 Jul 2023   Prob (F-statistic):          6.11e-104
# Time:                        21:51:51   Log-Likelihood:                -2302.0
# No. Observations:                 762   AIC:                             4612.
# Df Residuals:                     758   BIC:                             4631.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                13.5183      0.393     34.423      0.000      12.747      14.289
# ...

# %% [markdown]
# Provide model output and an interpretation of the results.

# %% [markdown]
# - There is a low adjusted R-squared, showing that COUNT_4SQUARE_POI, Count_Yelp_POI and Empty slots are small association between the available bike and the number POI as well as empty spots
# - p<0.05: rejected Null Hypothesis, the available bike are not normally distributed across the poin of interest.
# - Prob (F-statistic) is close to 0 show that there are no corellation between available bike and number of point of interest.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
